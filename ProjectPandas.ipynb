# %%
import pandas as pd
data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
columns =data.columns = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'Other']

# %%
data.head(5)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   Other
# 0             0             0              13   United-States   <=50K
# ...

# %%
data.workclass.unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
uni = []
for columns in data:
    uni.append(data[columns].unique())
uni
# Out:
# [array([50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43, 54,
#         35, 59, 56, 19, 39, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#         46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#         26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#         83, 84, 85, 86, 87], dtype=int64),
#  array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#         ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#         ' Never-worked'], dtype=object),
#  array([ 83311, 215646, 234721, ...,  34066,  84661, 257302], dtype=int64),
#  array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#         ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#         ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#         ' Preschool', ' 12th'], dtype=object),
#  array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8],
#        dtype=int64),
# ...

# %%
data1 = data.drop(columns=['fnlwgt', 'education', 'relationship'])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(data1.corr())

# %%
data1.isna().any()
# Out:
# age               False
# workclass         False
# education-num     False
# marital-status    False
# occupation        False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# Other             False
# dtype: bool

# %%
data1.head()
# Out:
#    age          workclass  education-num       marital-status  \
# 0   50   Self-emp-not-inc             13   Married-civ-spouse
# 1   38            Private              9             Divorced
# 2   53            Private              7   Married-civ-spouse
# 3   28            Private             13   Married-civ-spouse
# 4   37            Private             14   Married-civ-spouse
#
#            occupation    race      sex  capital-gain  capital-loss  \
# 0     Exec-managerial   White     Male             0             0
# 1   Handlers-cleaners   White     Male             0             0
# 2   Handlers-cleaners   Black     Male             0             0
# 3      Prof-specialty   Black   Female             0             0
# 4     Exec-managerial   White   Female             0             0
#
#    hours-per-week  native-country   Other
# 0              13   United-States   <=50K
# 1              40   United-States   <=50K
# 2              40   United-States   <=50K
# ...

# %%
x = data1.iloc[:, :-1].values

# %%
y = data1.iloc[:, -1].values

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
LabelX = LabelEncoder()

# %%
#x[:, [1,3,4,5,6,10]] = LabelX.fit_transform(x[:, [1,3,4,5,6,10]]) >> not method to converdatat,

data1 = data1.apply(LabelEncoder().fit_transform)
data1.head()
# Out:
#    age  workclass  education-num  marital-status  occupation  race  sex  \
# 0   33          6             12               2           4     4    1
# 1   21          4              8               0           6     4    1
# 2   36          4              6               2           6     2    1
# 3   11          4             12               2          10     2    0
# 4   20          4             13               2           4     4    0
#
#    capital-gain  capital-loss  hours-per-week  native-country  Other
# 0             0             0              12              39      0
# 1             0             0              39              39      0
# 2             0             0              39              39      0
# 3             0             0              39               5      0
# 4             0             0              39              39      0

# %%
uni = []
for columns in data1:
    uni.append(data1[columns].unique())
uni
# Out:
# [array([33, 21, 36, 11, 20, 32, 35, 14, 25, 13,  6, 15, 23, 17,  8, 26, 37,
#         18, 42, 39,  2, 22,  3, 28,  5, 31,  4,  7, 40, 27, 24, 12,  1, 30,
#         29, 19, 62, 10, 50, 16, 59,  0, 38, 44, 53, 47, 54, 51, 49, 34, 41,
#          9, 43, 72, 58, 48, 60, 45, 46, 63, 55, 57, 52, 56, 64, 61, 71, 65,
#         66, 67, 68, 69, 70], dtype=int64),
#  array([6, 4, 7, 1, 2, 0, 5, 8, 3], dtype=int64),
#  array([12,  8,  6, 13,  4,  9, 11, 10,  3, 15, 14,  2,  5,  1,  0,  7],
#        dtype=int64),
#  array([2, 0, 3, 4, 5, 1, 6], dtype=int64),
#  array([ 4,  6, 10,  8,  1, 12,  3, 14,  5,  7, 13,  0, 11,  2,  9],
#        dtype=int64),
#  array([4, 2, 1, 0, 3], dtype=int64),
#  array([1, 0], dtype=int64),
#  array([  0, 105,  79,  77,  34, 106, 108,  94, 116,  66,  68,  91,  11,
#          60,   6,  58,  22,  26,  25,   3, 111,  90,  67,   8,  97,  54,
#          39, 114,  71,  98,  36,  50, 102,  47,  53,  38,  59,  74, 118,
# ...
